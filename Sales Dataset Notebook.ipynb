# %% [markdown]
# # **The Analysis of Sales Dataset**

# %% [markdown]
# ## **About Data**
#
# Title       : Sales Dataset
#
# Dataset     : [link](https://www.kaggle.com/datasets/sahilislam007/sales-dataset)

# %% [markdown]
# ## **Import Libraries**

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## **Data Exploration**

# %% [markdown]
# ### **Download and Load CSV**

# %%
# Download csv

import kagglehub

path = kagglehub.dataset_download("sahilislam007/sales-dataset")

# %%
# Load csv
df = pd.read_csv(path + "/Sales Dataset.csv")

# %% [markdown]
# ### **Sneak Peak Data**

# %%
# See the top 5 of the data
df.head()
# Out:
#    Unnamed: 0        Date  Gender  Age Product Category  Quantity  \
# 0           0  2023-11-24    Male   34           Beauty         3
# 1           1  2023-02-27  Female   26         Clothing         2
# 2           2  2023-01-13    Male   50      Electronics         1
# 3           3  2023-05-21    Male   37         Clothing         1
# 4           4  2023-05-06    Male   30           Beauty         2
#
#    Price per Unit  Total Amount
# 0              50           150
# 1             500          1000
# 2              30            30
# 3             500           500
# 4              50           100

# %%
# See the columns name
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Gender', 'Age', 'Product Category', 'Quantity',
#        'Price per Unit', 'Total Amount'],
#       dtype='object')

# %%
# See the data's shape
print(f"There are {df.shape[0]} rows and {df.shape[1]} columns")
# Out:
# There are 1000 rows and 8 columns

# %%
# See the columns details
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Gender            1000 non-null   object
#  3   Age               1000 non-null   int64
#  4   Product Category  1000 non-null   object
#  5   Quantity          1000 non-null   int64
#  6   Price per Unit    1000 non-null   int64
#  7   Total Amount      1000 non-null   int64
# dtypes: int64(5), object(3)
# memory usage: 62.6+ KB

# %%
# Count null values
df.isna().sum()
# Out:
# Unnamed: 0          0
# Date                0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64

# %% [markdown]
# ### **Findings**
# 1. There are 1000 rows and 8 columns
# 2. The columns of the dataset are:
#
#       (['Unnamed: 0', 'Date', 'Gender', 'Age', 'Product Category', 'Quantity',
#        'Price per Unit', 'Total Amount'])
# 3. There are some columns that have wrong datatype
# 4. There is no missing or null value
# 5. There is a unknown column's name

# %% [markdown]
# ### **Change Column Name**

# %%
# Copy the original table
df_sales = df.copy()

# %%
# Changing unknown column's name
df_sales.rename(columns={'Unnamed: 0' : 'Row Number'}, inplace=True)

# %%
# Check changing
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Row Number        1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Gender            1000 non-null   object
#  3   Age               1000 non-null   int64
#  4   Product Category  1000 non-null   object
#  5   Quantity          1000 non-null   int64
#  6   Price per Unit    1000 non-null   int64
#  7   Total Amount      1000 non-null   int64
# dtypes: int64(5), object(3)
# memory usage: 62.6+ KB

# %% [markdown]
# ### **Change Columns Datatype**

# %%
# Change Date column datatype from object to datetime
df_sales['Date'] = pd.to_datetime(df_sales['Date'])

# %%
# Check changing
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Row Number        1000 non-null   int64
#  1   Date              1000 non-null   datetime64[ns]
#  2   Gender            1000 non-null   object
#  3   Age               1000 non-null   int64
#  4   Product Category  1000 non-null   object
#  5   Quantity          1000 non-null   int64
#  6   Price per Unit    1000 non-null   int64
#  7   Total Amount      1000 non-null   int64
# dtypes: datetime64[ns](1), int64(5), object(2)
# memory usage: 62.6+ KB

# %% [markdown]
# ### **Change Column Values**
# The row number start with 0, so I want to change the number with +1 for all the row number

# %%
# Change row number values
df_sales['Row Number'] = df_sales['Row Number'] + 1

# %%
# Check row number changing
df_sales.head()
# Out:
#    Row Number       Date  Gender  Age Product Category  Quantity  \
# 0           1 2023-11-24    Male   34           Beauty         3
# 1           2 2023-02-27  Female   26         Clothing         2
# 2           3 2023-01-13    Male   50      Electronics         1
# 3           4 2023-05-21    Male   37         Clothing         1
# 4           5 2023-05-06    Male   30           Beauty         2
#
#    Price per Unit  Total Amount
# 0              50           150
# 1             500          1000
# 2              30            30
# 3             500           500
# 4              50           100

# %% [markdown]
# ### **Check Other Columns For Possible Error**

# %%
# Check the unique values in gender column
df_sales['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
# Check the unique values in age column
df_sales['Age'].unique()
# Out:
# array([34, 26, 50, 37, 30, 45, 46, 63, 52, 23, 35, 22, 64, 42, 19, 27, 47,
#        62, 18, 49, 28, 38, 43, 39, 44, 51, 58, 48, 55, 20, 40, 54, 36, 31,
#        21, 57, 25, 56, 29, 61, 32, 41, 59, 60, 33, 53, 24])

# %%
# Check the unique values in product category column
df_sales['Product Category'].unique()
# Out:
# array(['Beauty', 'Clothing', 'Electronics'], dtype=object)

# %% [markdown]
# ### **Duplicates**

# %%
# Show duplicate
df_sales_duplicate = df_sales.duplicated()

# %%
# Show all duplicates
print(df_sales_duplicate)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %% [markdown]
# ## **Data Transformation**

# %%
df_sales.head()
# Out:
#    Row Number       Date  Gender  Age Product Category  Quantity  \
# 0           1 2023-11-24    Male   34           Beauty         3
# 1           2 2023-02-27  Female   26         Clothing         2
# 2           3 2023-01-13    Male   50      Electronics         1
# 3           4 2023-05-21    Male   37         Clothing         1
# 4           5 2023-05-06    Male   30           Beauty         2
#
#    Price per Unit  Total Amount
# 0              50           150
# 1             500          1000
# 2              30            30
# 3             500           500
# 4              50           100

# %% [markdown]
# ### **Add Days Name Columns**

# %%
# Add days name
df_sales['Day'] = df_sales['Date'].dt.day_name()

# %%
# Check the new column
df_sales.head()
# Out:
#    Row Number       Date  Gender  Age Product Category  Quantity  \
# 0           1 2023-11-24    Male   34           Beauty         3
# 1           2 2023-02-27  Female   26         Clothing         2
# 2           3 2023-01-13    Male   50      Electronics         1
# 3           4 2023-05-21    Male   37         Clothing         1
# 4           5 2023-05-06    Male   30           Beauty         2
#
#    Price per Unit  Total Amount       Day
# 0              50           150    Friday
# 1             500          1000    Monday
# 2              30            30    Friday
# 3             500           500    Sunday
# 4              50           100  Saturday

# %% [markdown]
# ### **Add Age Segment Column**

# %%
# Add age segment column
df_sales['Age Segment'] = np.where(df_sales['Age'] <= 17, 'Youth',
                            np.where(df_sales['Age'] <= 34, 'Young Adult',
                            np.where(df_sales['Age'] <= 54, 'Adult','Senior')))

# %%
# Check the new column
df_sales.head()
# Out:
#    Row Number       Date  Gender  Age Product Category  Quantity  \
# 0           1 2023-11-24    Male   34           Beauty         3
# 1           2 2023-02-27  Female   26         Clothing         2
# 2           3 2023-01-13    Male   50      Electronics         1
# 3           4 2023-05-21    Male   37         Clothing         1
# 4           5 2023-05-06    Male   30           Beauty         2
#
#    Price per Unit  Total Amount       Day  Age Segment
# 0              50           150    Friday  Young Adult
# 1             500          1000    Monday  Young Adult
# 2              30            30    Friday        Adult
# 3             500           500    Sunday        Adult
# 4              50           100  Saturday  Young Adult

# %% [markdown]
# ### **Add Month and Monthly Sales Columns**

# %%
# Add month column
df_sales['Month'] = df_sales['Date'].dt.to_period('M')

# %%
# Check new column
df_sales.head()
# Out:
#    Row Number       Date  Gender  Age Product Category  Quantity  \
# 0           1 2023-11-24    Male   34           Beauty         3
# 1           2 2023-02-27  Female   26         Clothing         2
# 2           3 2023-01-13    Male   50      Electronics         1
# 3           4 2023-05-21    Male   37         Clothing         1
# 4           5 2023-05-06    Male   30           Beauty         2
#
#    Price per Unit  Total Amount       Day  Age Segment    Month
# 0              50           150    Friday  Young Adult  2023-11
# 1             500          1000    Monday  Young Adult  2023-02
# 2              30            30    Friday        Adult  2023-01
# 3             500           500    Sunday        Adult  2023-05
# 4              50           100  Saturday  Young Adult  2023-05

# %%
# Add monthly sales column
df_sales['Monthly Sales'] = df_sales.groupby('Month')['Total Amount'].transform('sum')

# %%
# Check new column
df_sales.head()
# Out:
#    Row Number       Date  Gender  Age Product Category  Quantity  \
# 0           1 2023-11-24    Male   34           Beauty         3
# 1           2 2023-02-27  Female   26         Clothing         2
# 2           3 2023-01-13    Male   50      Electronics         1
# 3           4 2023-05-21    Male   37         Clothing         1
# 4           5 2023-05-06    Male   30           Beauty         2
#
#    Price per Unit  Total Amount       Day  Age Segment    Month  Monthly Sales
# 0              50           150    Friday  Young Adult  2023-11          34920
# 1             500          1000    Monday  Young Adult  2023-02          44060
# 2              30            30    Friday        Adult  2023-01          35450
# 3             500           500    Sunday        Adult  2023-05          53150
# 4              50           100  Saturday  Young Adult  2023-05          53150

# %% [markdown]
# ### **Add Quarter and Quarter Sales Columns**

# %%
# Add quarter column
df_sales['Quarter'] = 'Q' + df_sales['Date'].dt.quarter.astype(str)

# %%
# Check new column
df_sales.head()
# Out:
#    Row Number       Date  Gender  Age Product Category  Quantity  \
# 0           1 2023-11-24    Male   34           Beauty         3
# 1           2 2023-02-27  Female   26         Clothing         2
# 2           3 2023-01-13    Male   50      Electronics         1
# 3           4 2023-05-21    Male   37         Clothing         1
# 4           5 2023-05-06    Male   30           Beauty         2
#
#    Price per Unit  Total Amount       Day  Age Segment    Month  \
# 0              50           150    Friday  Young Adult  2023-11
# 1             500          1000    Monday  Young Adult  2023-02
# 2              30            30    Friday        Adult  2023-01
# 3             500           500    Sunday        Adult  2023-05
# 4              50           100  Saturday  Young Adult  2023-05
#
#    Monthly Sales Quarter
# 0          34920      Q4
# 1          44060      Q1
# 2          35450      Q1
# 3          53150      Q2
# 4          53150      Q2

# %%
# Add quarter sales column
df_sales['Quarter Sales'] = df_sales.groupby('Quarter')['Total Amount'].transform('sum')

# %%
# Check new column
df_sales.head()
# Out:
#    Row Number       Date  Gender  Age Product Category  Quantity  \
# 0           1 2023-11-24    Male   34           Beauty         3
# 1           2 2023-02-27  Female   26         Clothing         2
# 2           3 2023-01-13    Male   50      Electronics         1
# 3           4 2023-05-21    Male   37         Clothing         1
# 4           5 2023-05-06    Male   30           Beauty         2
#
#    Price per Unit  Total Amount       Day  Age Segment    Month  \
# 0              50           150    Friday  Young Adult  2023-11
# 1             500          1000    Monday  Young Adult  2023-02
# 2              30            30    Friday        Adult  2023-01
# 3             500           500    Sunday        Adult  2023-05
# 4              50           100  Saturday  Young Adult  2023-05
#
#    Monthly Sales Quarter  Quarter Sales
# 0          34920      Q4         126190
# 1          44060      Q1         110030
# 2          35450      Q1         110030
# 3          53150      Q2         123735
# 4          53150      Q2         123735

# %% [markdown]
# ### **Add Monthly Growth Percentation**

# %%
# Rearrange rows based on oldest date
df_sales = df_sales.sort_values(by='Date', ascending=True)

# %%
# Because of the rearrange rows, row number become random
# So, I reset the row number 
df_sales['Row Number'] = df_sales.index + 1

# %%
# Check changing
df_sales.head()
# Out:
#    Row Number       Date  Gender  Age Product Category  Quantity  \
# 0           1 2023-01-01    Male   46           Beauty         3
# 1           2 2023-01-01    Male   41         Clothing         3
# 2           3 2023-01-01  Female   40         Clothing         4
# 3           4 2023-01-02    Male   19      Electronics         3
# 4           5 2023-01-02  Female   19           Beauty         1
#
#    Price per Unit  Total Amount     Day  Age Segment    Month  Monthly Sales  \
# 0             500          1500  Sunday        Adult  2023-01          35450
# 1             300           900  Sunday        Adult  2023-01          35450
# 2             300          1200  Sunday        Adult  2023-01          35450
# 3              30            90  Monday  Young Adult  2023-01          35450
# 4              25            25  Monday  Young Adult  2023-01          35450
#
#   Quarter  Quarter Sales
# 0      Q1         110030
# 1      Q1         110030
# 2      Q1         110030
# 3      Q1         110030
# 4      Q1         110030

# %% [markdown]
# 1. Rearrange rows based date
# 2. Search %growth = (thismonth - lastmonth)/lastmonth
# 3. lastmonth using .shift()
# 4. create pivot table
#     - Age segment behavior (total spending, product category, when)
#     - weekly, monthly, and quarter customer behavior
#     - Gender spending behavior
